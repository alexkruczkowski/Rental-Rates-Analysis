# %% [markdown]
# Analyzing rate seasonality and ways to save money in the rental market
#
# Data from Zillow -> Metro U.S. Smoothed Rental Rates

# %%
import pandas as pd

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# Import the rental data, filter down to a city level, change date to datetime format, set the date as the index, and pivot the data to prepare for use in the SARIMAX model/analysis

# %%
df = pd.read_csv(r'data/MetroUSSmoothed.csv')

df
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1383.0     1391
# 1      394913                        New York, NY         1   2370.0     2390
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1884.0     1903
# 3      394463                         Chicago, IL         3   1458.0     1468
# 4      394514               Dallas-Fort Worth, TX         4   1212.0     1215
# ..        ...                                 ...       ...      ...      ...
# 102    394602                    Fort Collins, CO       159   1199.0     1190
# 103    394405                         Boulder, CO       162   1568.0     1465
# 104    394645                         Greeley, CO       177   1222.0     1190
# 105    394623                     Gainesville, GA       229    912.0      929
# 106    395098                    Sierra Vista, AZ       309    990.0      997
#
# ...

# %%
df_filter = df[(df['SizeRank']>=1) & (df['SizeRank']<=50)]

df_filter
# Out:
#     RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 1     394913                        New York, NY         1   2370.0     2390
# 2     753899  Los Angeles-Long Beach-Anaheim, CA         2   1884.0     1903
# 3     394463                         Chicago, IL         3   1458.0     1468
# 4     394514               Dallas-Fort Worth, TX         4   1212.0     1215
# 5     394974                    Philadelphia, PA         5   1380.0     1368
# 6     394692                         Houston, TX         6   1264.0     1264
# 7     395209                      Washington, DC         7   1876.0     1880
# 8     394856           Miami-Fort Lauderdale, FL         8   1572.0     1567
# 9     394347                         Atlanta, GA         9   1129.0     1136
# 10    394404                          Boston, MA        10   1997.0     2028
# 11    395057                   San Francisco, CA        11   2203.0     2286
# ...

# %%
df_cities = df_filter.drop(['RegionID', 'SizeRank'], axis = 1) 

df_cities
# Out:
#                             RegionName  2014-01  2014-02  2014-03  2014-04  \
# 1                         New York, NY   2370.0     2390     2395     2426
# 2   Los Angeles-Long Beach-Anaheim, CA   1884.0     1903     1909     1933
# 3                          Chicago, IL   1458.0     1468     1472     1491
# 4                Dallas-Fort Worth, TX   1212.0     1215     1218     1231
# 5                     Philadelphia, PA   1380.0     1368     1379     1388
# 6                          Houston, TX   1264.0     1264     1280     1320
# 7                       Washington, DC   1876.0     1880     1881     1895
# 8            Miami-Fort Lauderdale, FL   1572.0     1567     1570     1580
# 9                          Atlanta, GA   1129.0     1136     1137     1147
# 10                          Boston, MA   1997.0     2028     2020     2041
# 11                   San Francisco, CA   2203.0     2286     2283     2298
# ...

# %%
df_hous = df_cities[df_cities['RegionName'] == 'Houston, TX']   

df_hous
# Out:
#     RegionName  2014-01  2014-02  2014-03  2014-04  2014-05  2014-06  2014-07  \
# 6  Houston, TX   1264.0     1264     1280     1320     1345     1363     1379
#
#    2014-08  2014-09  ...  2020-01  2020-02  2020-03  2020-04  2020-05  \
# 6     1383     1381  ...     1506     1511     1516     1512     1503
#
#    2020-06  2020-07  2020-08  2020-09  2020-10
# 6     1504     1502     1503     1506   1505.0
#
# [1 rows x 83 columns]

# %%
df_test = df_hous.melt(id_vars=["RegionName"], 
        var_name="Date", 
        value_name="Value")

df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionName  82 non-null     object
#  1   Date        82 non-null     object
#  2   Value       82 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 2.0+ KB

# %%
df_test
# Out:
#      RegionName     Date   Value
# 0   Houston, TX  2014-01  1264.0
# 1   Houston, TX  2014-02  1264.0
# 2   Houston, TX  2014-03  1280.0
# 3   Houston, TX  2014-04  1320.0
# 4   Houston, TX  2014-05  1345.0
# ..          ...      ...     ...
# 77  Houston, TX  2020-06  1504.0
# 78  Houston, TX  2020-07  1502.0
# 79  Houston, TX  2020-08  1503.0
# 80  Houston, TX  2020-09  1506.0
# 81  Houston, TX  2020-10  1505.0
#
# [82 rows x 3 columns]

# %%
df_test['Date']= pd.to_datetime(df_test['Date'])

df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionName  82 non-null     object
#  1   Date        82 non-null     datetime64[ns]
#  2   Value       82 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 2.0+ KB

# %%
df_test2 = df_test.drop(['RegionName'], axis = 1) 

df_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    82 non-null     datetime64[ns]
#  1   Value   82 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.4 KB

# %%
df_test2.set_index('Date', inplace=True)

df_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 82 entries, 2014-01-01 to 2020-10-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   82 non-null     float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %%
df_test2
# Out:
#              Value
# Date
# 2014-01-01  1264.0
# 2014-02-01  1264.0
# 2014-03-01  1280.0
# 2014-04-01  1320.0
# 2014-05-01  1345.0
# ...            ...
# 2020-06-01  1504.0
# 2020-07-01  1502.0
# 2020-08-01  1503.0
# 2020-09-01  1506.0
# 2020-10-01  1505.0
#
# [82 rows x 1 columns]

# %% [markdown]
# ## Visualizing the Data

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
import pandas as pd
import statsmodels.api as sm
import matplotlib
plt.style.use('default')
from statsmodels.tsa.seasonal import seasonal_decompose

df_test2.plot(figsize=(15, 6))
plt.ylabel('price ($)')
plt.title('Houston Rent Prices', fontsize=24)
plt.show()

# plt.savefig('houstonrent.png')

# %% [markdown]
# Some patterns emerge, with what looks to be fairly consistent decreases around year end, with a consistent upwards trend in rental rates since the end of 2014.

# %% [markdown]
# ## Data Analysis and Initial Model Results

# %% [markdown]
# Split the trend, seasonality, and noise factors out of the original rent trends using time-series seasonal decompososition.
#
# As we can see by the seasonality results below, there is typically an uptick in rent prices mid-year around June, with the lowest prices being available in January. There is a gradual upwards trend in price, that has remained consistent over the years in the data available.

# %%
components = seasonal_decompose(df_test2, model='additive')

plt.rcParams["figure.figsize"] = [12,8]
fig = components.plot()
fig.subplots_adjust(top=0.92)
fig.suptitle("Houston Seasonal Decomposition", fontsize=22)

plt.show()

# plt.savefig('houstonSD.png')

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# Find the best paramaters for the SARIMAX model using the code below. I am looking for the paramaters with the lowest AIC values.

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df_test2,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
  
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1410.3566193535582
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1130.0072603117083
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:701.3371894289737
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:536.853488097159
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:680.9405932195691
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:649.1604476729755
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:544.5693000964343
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:538.1137183747268
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1288.5415524765535
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1027.2589866812257
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:597.4176510957319
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:463.8310653391304
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:685.1899334103035
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:557.5221817089385
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:478.39603337958914
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:464.2553966426915
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:564.0053321047546
# ...

# %% [markdown]
# ## Examining Model Results

# %% [markdown]
# Use the paramters ARIMA(1, 1, 1)x(1, 1, 1, 12) for Houston as they had the lowest AIC of 334.91.
#
# Check the model results and see how the results are distributed.

# %%
mod = sm.tsa.statespace.SARIMAX(df_test2,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Value   No. Observations:                   82
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -162.454
# Date:                            Sat, 19 Dec 2020   AIC                            334.908
# Time:                                    14:07:03   BIC                            344.945
# Sample:                                01-01-2014   HQIC                           338.789
#                                      - 10-01-2020
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4292      0.246      1.744      0.081      -0.053       0.911
# ma.L1          0.2418      0.257      0.939      0.348      -0.263       0.746
# ...

# %% [markdown]
# Model looks to have a relatively normal distribution

# %%
results.plot_diagnostics(figsize=(16, 8))
# plt.show()

# plt.savefig('houstonmodeldiagnostics.png')

# %% [markdown]
# The model looks to be fairly normally distributed with normal skew and a high kurtosis of 3.75 indicating that there may be more outliers. For a rough analysis, this should be ok

# %%
pred = results.get_prediction(start=pd.to_datetime('2020-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = df_test2['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Rent')
plt.title('Houston Forecasted Prices vs. Actual', fontsize=24)
plt.legend()
plt.show()

# plt.savefig('houstonFvsA.png')

# %% [markdown]
# The forecast for the model is fairly close to the actual values, looking good so far!

# %% [markdown]
# And finally, lets check the mean squared error and root mean squared error.

# %%
from sklearn.metrics import mean_squared_error

y_forecast = list(pred.predicted_mean)
yt = df_test2['2020-01-01':]
y_truth = yt['Value'].tolist()

mse = mean_squared_error(y_truth, y_forecast)
rmse = mean_squared_error(y_truth, y_forecast, squared=False)

print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 26.52
# The Root Mean Squared Error of our forecasts is 5.15

# %% [markdown]
# In statistics, the mean squared error (MSE) of an estimator measures the average of the squares of the errors — that is, the average squared difference between the estimated values and what is estimated. The MSE is a measure of the quality of an estimator—it is always non-negative, and the smaller the MSE, the closer we are to finding the line of best fit.
#
# <b>(Source: Susan Li)</b>
#
# Root Mean Square Error (RMSE) tells us that our model was able to forecast the average monthly rent price within $5.15 of the real rent. The Houston rental prices can fluctuate between 5 - 30 dollars per month. In my opinion, this is a pretty good model so far.

# %% [markdown]
# ## Final Forecast

# %% [markdown]
# Forecasting for the next 24 months to see how rent prices will perform

# %%
pred_uc = results.get_forecast(steps=24)
pred_ci = pred_uc.conf_int()
ax = df_test2.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Rent Price')
plt.title('Houston Rent Forecast', fontsize=24)
plt.legend()
plt.show()

# plt.savefig('houstonrentprediction.png')

# %% [markdown]
# Our model clearly captured rental rate seasonality. As we forecast further into the future, it is natural for us to become less confident in our values. This is reflected in the confidence intervals generated by the model, which grows larger as we move further into the future.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The best time to start renting in Houston, Texas is in January when prices are the lowest as indicated by the seasonal decomposition charts. As there continues to be an upwards trend in rental prices, longer term rentals in the form of two year leases would likely prove to be the least expensive.
#
# In addition, with the recent exodus of companies from San Francisco and NYC it is possible that Houston will see more high earning tech workers join the city and subsequently see an increase in rental prices as supply drops and willingness to pay increases.
